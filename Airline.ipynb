# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
from collections import Counter

# %%
plt.style.use("seaborn-v0_8")
df = pd.read_csv("airline_passenger_satisfaction.csv")

df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
df.describe(include="object")
# Out:
#         Gender Customer Type Type of Travel     Class             Satisfaction
# count   129880        129880         129880    129880                   129880
# unique       2             2              2         3                        2
# top     Female     Returning       Business  Business  Neutral or Dissatisfied
# freq     65899        106100          89693     62160                    73452

# %% [markdown]
# # Conclusion
# - The /data shape is (129880,24)
# - There are null values only in Arrival column
# - Columns ['Departure and Arrival Time Convenience' - 'Baggage Handling'] have int values [0,5] --> Clean already
# - Columns with object datatype has no missing values

# %% [markdown]
# # Cleaning

# %% [markdown]
# ## Nan values

# %%
df = df.dropna()

# %% [markdown]
# ## Clean Flight Distance

# %%
Q1 = df["Flight Distance"].quantile(0.25)
Q3 = df["Flight Distance"].quantile(0.75)
IQR = Q3 - Q1
df = df[
    ~(
        (df["Flight Distance"] < (Q1 - 1.5 * IQR))
        | (df["Flight Distance"] > (Q3 + 1.5 * IQR))
    )
]

# %% [markdown]
# ## Departure Delay

# %%
Q1 = df["Departure Delay"].quantile(0.25)
Q3 = df["Departure Delay"].quantile(0.75)
IQR = Q3 - Q1
df = df[
    ~(
        (df["Departure Delay"] < (Q1 - 1.5 * IQR))
        | (df["Departure Delay"] > (Q3 + 1.5 * IQR))
    )
]

# %% [markdown]
# ## Arrival Delay

# %%
df = df[df["Arrival Delay"] <= 20]
# custom value

# %% [markdown]
# # Visualisation

# %% [markdown]
# ## Gender

# %%
gender = df["Gender"].value_counts()
label = gender.index
color = ["#f5ff00", "#34499f"]
plt.pie(
    gender,
    labels=label,
    colors=color,
    wedgeprops={"edgecolor": "white", "linewidth": 3},
    autopct="%.2f",
)
plt.show()

# %% [markdown]
# ## Age

# %%
age = df["Age"]
bins = np.arange(10, 100, 10)
plt.hist(age, bins=bins, edgecolor="black")
plt.ylabel("Number of travelers")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# - Most of the passengers are `40 - 50` years old.

# %% [markdown]
# ## Customer type

# %%
cType = df["Customer Type"]
label = cType.value_counts().index
color = ["#f5ff00", "#34499f"]
plt.pie(
    cType.value_counts(),
    labels=label,
    colors=color,
    wedgeprops={"edgecolor": "white", "linewidth": 3},
    autopct="%.2f",
)
plt.show()

# %% [markdown]
# ## Type of travel

# %%
travel = df["Type of Travel"].value_counts()
# travel

# %%
plt.pie(
    travel,
    labels=travel.index,
    autopct="%.2f",
    wedgeprops={"edgecolor": "white", "linewidth": 3},
)
## most travels are Business ones
# Out:
# ([<matplotlib.patches.Wedge at 0x21eafcfbb00>,
# ...
#  [Text(-0.5985901402513146, 0.9228704372737875, 'Business'),
#   Text(0.5985902266566785, -0.9228703812297296, 'Personal')],
#  [Text(-0.32650371286435337, 0.5033838748766113, '68.32'),
#   Text(0.32650375999455183, -0.5033838443071252, '31.68')])

# %% [markdown]
# ## Class

# %%
cls = df["Class"].value_counts()
plt.pie(
    cls,
    labels=cls.index,
    autopct="%.2f",
    wedgeprops={"edgecolor": "white", "linewidth": 2},
)
plt.show()

# %%
classes = df["Class"].unique()
satisfied = []
disSatisfied = []
for c in classes:
    s = df[df["Class"] == c]["Satisfaction"].value_counts()
    satisfied.append(s["Satisfied"])
    disSatisfied.append(s["Neutral or Dissatisfied"])

fig, ax = plt.subplots()
ax.bar(classes, satisfied, label="Satisfied", width=0.5)
ax.bar(classes, disSatisfied, bottom=satisfied, label="Dissatisfied", width=0.5)
plt.title("Satisfaction of Travellers")
plt.xlabel("Class")
plt.ylabel("Number of Travellers")
ax.legend()
plt.show()

# %% [markdown]
# > most people in business class are satisfied but in economy and economy plus classes the majority are dissatisfied

# %% [markdown]
# ## Flight Distance

# %%
flights = df["Flight Distance"]
plt.hist(flights, bins=20, edgecolor="black")
plt.show()

# %% [markdown]
# > Most flights are in range`[0,1000]`

# %% [markdown]
# ## Departure delay

# %%
departure = df["Departure Delay"]
plt.hist(departure, bins=6, edgecolor="black", log=True)
# Out:
# (array([80641.,  8045.,  5411.,  3612.,  2280.,  1468.]),
#  array([ 0.,  5., 10., 15., 20., 25., 30.]),
#  <BarContainer object of 6 artists>)

# %%
dist_Dept = (
    df[["Flight Distance", "Departure Delay"]].set_index("Flight Distance").sort_index()
)

# %%
plt.scatter(dist_Dept.index, dist_Dept["Departure Delay"])

# %% [markdown]
# > Departure Delay is relatively higher within distance `0-1000` which has the largest section of flights

# %%
Dept_Dissat = df[df["Satisfaction"] == "Neutral or Dissatisfied"]["Departure Delay"]
Dept_Sat = df[df["Satisfaction"] != "Neutral or Dissatisfied"]["Departure Delay"]
labels = ["Satisfied", "Dissatisfied"]
plt.hist(
    (Dept_Sat, Dept_Dissat),
    density=False,
    bins=10,
    edgecolor="black",
    label=labels,
    log=True,
)
plt.legend()

# %% [markdown]
# > Seemingly no relation between dept delay and Satisfacion

# %% [markdown]
# ## Arrival Delay

# %%
plt.hist(df["Arrival Delay"], bins=5, edgecolor="black")
# Out:
# (array([78714.,  8023.,  5977.,  4581.,  4162.]),
#  array([ 0.,  4.,  8., 12., 16., 20.]),
#  <BarContainer object of 5 artists>)

# %%
arr = df[["Flight Distance", "Arrival Delay"]].set_index("Flight Distance").sort_index()

# %%
plt.scatter(arr.index, arr["Arrival Delay"])

# %% [markdown]
# > Arrival delay is also higher in range `0-1000` distance

# %%
Arr_Sat = df[df["Satisfaction"] != "Neutral or Dissatisfied"]["Arrival Delay"]
Arr_Dissat = df[df["Satisfaction"] == "Neutral or Dissatisfied"]["Arrival Delay"]
labels = ["Satisfied", "Dissatisfied"]
plt.hist((Arr_Sat, Arr_Dissat), bins=10, edgecolor="black", label=labels, log=True)
plt.legend()

# %% [markdown]
# > Seemingly no relation between Arrival delay and Satisfacion
